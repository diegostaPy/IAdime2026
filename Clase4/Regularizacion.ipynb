# %% [markdown]
# ## Regresion lineal Reguralizacion Lasso y Rigde

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import Pipeline

# %%
np.random.seed(42)
m = 100
X = 4 * np.random.rand(m, 1)
y = 2 + 1.0 * X+ 0.5 * X*X *X+ np.random.randn(m, 1)

# %%
plt.plot(X, y, "b.", linewidth=3)

# %%
from sklearn.linear_model import SGDRegressor
sgd= SGDRegressor(max_iter=50, penalty=None, eta0=0.1  , random_state=42)
sgd.fit(X, y)
# Out:
# h:\Anaconda\envs\IA\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor(eta0=0.1, max_iter=50, penalty=None, random_state=42)

# %%
sgd.intercept_, sgd.coef_
# Out:
# (array([-3.10370028]), array([8.43636327]))

# %%
sgd = SGDRegressor(max_iter=50, penalty=None, eta0=0.1  , random_state=42)
sgd.fit(np.hstack((X,X*X)), y)
# Out:
# h:\Anaconda\envs\IA\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor(eta0=0.1, max_iter=50, penalty=None, random_state=42)

# %%
sgd.intercept_, sgd.coef_
# Out:
# (array([5.20220131e+09]), array([-7.68735536e+09,  1.55634623e+09]))

# %%
X_new = np.linspace(0, 3, 100).reshape(100, 1)

# %%
ypred = sgd.predict(np.hstack((X_new,X_new*X_new)))

# %%
plt.plot(X, y, "b.", linewidth=3)
plt.plot(X_new, ypred, "-", linewidth=1)

# %%
sgd = SGDRegressor(max_iter=50, penalty=None, eta0=0.1  , random_state=42)
sgd.fit(np.hstack((X,X*X*X)), y)
# Out:
# h:\Anaconda\envs\IA\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor(eta0=0.1, max_iter=50, penalty=None, random_state=42)

# %%
sgd.intercept_, sgd_reg.coef_
# Out:
# (array([8.8685312e+10]), array([-1.28802697e+11, -1.95747126e+11]))

# %%
ypred = sgd.predict(np.hstack((X_new,X_new*X_new*X_new)))

# %%
plt.plot(X, y, "b.", linewidth=3)
plt.plot(X_new, ypred, "-", linewidth=1)

# %%
from sklearn.preprocessing import PolynomialFeatures
polybig_features = PolynomialFeatures(degree=10, include_bias=False)

# %%
X_sca=polybig_features.fit_transform(X)

# %%
from sklearn.pipeline import Pipeline

# %%
polynomial_regression = Pipeline([('poly_features',PolynomialFeatures(degree=3, include_bias=False)),        
                                  ('lin_reg',SGDRegressor())
        ])
#polynomial_regression = Pipeline([('poly_features',PolynomialFeatures(degree=3, include_bias=False)),        
#                                  ('lin_reg',LinearRegression())
#        ])

polynomial_regression.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[80], line 8
#       1 polynomial_regression = Pipeline([('poly_features',PolynomialFeatures(degree=3, include_bias=False)),
#       2                                   ('lin_reg',SGDRegressor(loss="squared_loss", penalty=None))
#       3         ])
#       4 #polynomial_regression = Pipeline([('poly_features',PolynomialFeatures(degree=3, include_bias=False)),
#       5 #                                  ('lin_reg',LinearRegression())
#       6 #        ])
# ----> 8 polynomial_regression.fit(X,y)
#
# File h:\Anaconda\envs\IA\lib\site-packages\sklearn\pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
# ...

# %%
y_new_regul = polynomial_regression.predict(X_new)

# %%
plt.plot(X, y, "b.", linewidth=3)
plt.plot(X_new, y_new_regul, "-", linewidth=1)

# %% [markdown]
# ## Metodo de Rigde L2
# ![image.png](attachment:22f69162-019f-4e93-9a7e-7c746cc51166.png)

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.1, random_state=42)
ridge_reg.fit(X, y)
ridge_reg.predict([[1.5]])
# Out:
# array([[8.29702133]])

# %%
plt.plot(X, y, "b.", linewidth=3)
y_r= ridge_reg.predict(X)
plt.plot(X, y_r,  linewidth=1, label="Ridge")
plt.legend(loc="upper left", fontsize=15)
plt.xlabel("$x_1$", fontsize=18)
plt.axis([0, 4, 0, 9])
# Out:
# (0.0, 4.0, 0.0, 9.0)

# %%
sgd_reg = SGDRegressor(max_iter=1000, tol=-np.infty, penalty="l2", random_state=42)
sgd_reg.fit(X, y.ravel())
sgd_reg.predict([[1.5]])
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[65], line 2
#       1 sgd_reg = SGDRegressor(max_iter=1000, tol=-np.infty, penalty="l2", random_state=42)
# ----> 2 sgd_reg.fit(X, y.ravel())
#       3 sgd_reg.predict([[1.5]])
#
# File h:\Anaconda\envs\IA\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1582, in BaseSGDRegressor.fit(self, X, y, coef_init, intercept_init, sample_weight)
#    1557 def fit(self, X, y, coef_init=None, intercept_init=None, sample_weight=None):
#    1558     """Fit linear model with Stochastic Gradient Descent.
#    1559
#    1560     Parameters
#    (...)
#    1580         Fitted `SGDRegressor` estimator.
#    1581     """
# -> 1582     self._validate_params()
#    1583     self._more_validate_params()
#    1585     return self._fit(
#    1586         X,
#    1587         y,
#    (...)
# ...

# %%
plt.plot(X, y, "b.", linewidth=3)
y_r=sgd_reg.predict(X)
plt.plot(X, y_r,  linewidth=1, label="Ridge")
plt.legend(loc="upper left", fontsize=15)
plt.xlabel("$x_1$", fontsize=18)
plt.axis([0, 4, 0, 9])
# Out:
# (0.0, 4.0, 0.0, 9.0)

# %%
def plot_model(model_class, polynomial, alphas, **model_kargs):
    for alpha, style in zip(alphas, ("b-", "g--", "r:")):
        model = model_class(alpha, **model_kargs) if alpha > 0 else LinearRegression()
        if polynomial:
            model = Pipeline([
                    ("poly_features", PolynomialFeatures(degree=10, include_bias=False)),
                    ("std_scaler", StandardScaler()),
                    ("regul_reg", model),
                ])
        model.fit(X, y)
        y_new_regul = model.predict(X_new)
        lw = 2 if alpha > 0 else 1
        plt.plot(X_new, y_new_regul, style, linewidth=lw, label=r"$\alpha = {}$".format(alpha))
    plt.plot(X, y, "b.", linewidth=3)
    plt.legend(loc="upper left", fontsize=15)
    plt.xlabel("$x_1$", fontsize=18)
    plt.axis([0, 4, 0, 9])

plt.figure(figsize=(10,6))
plt.subplot(121)
plot_model(Ridge, polynomial=False, alphas=(0, 10, 100), random_state=42)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.subplot(122)
plot_model(Ridge, polynomial=True, alphas=(0, 10**-5, 1), random_state=42)

plt.show()

# %% [markdown]
# # Metodo de Lasso L1
#
# ![image.png](attachment:ffdc74ab-d078-4ea0-b5ec-516cf56e81f1.png)

# %%
from sklearn.linear_model import Lasso

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.1)
lasso_reg.fit(X, y)
# Out:
# Lasso(alpha=0.1)

# %%
plt.plot(X, y, "b.", linewidth=3)
y_r=lasso_reg.predict(X)
plt.plot(X, y_r,  linewidth=1, label="Lasso")
plt.legend(loc="upper left", fontsize=15)
plt.xlabel("$x_1$", fontsize=18)
plt.axis([0, 4, 0, 9])
# Out:
# (0.0, 4.0, 0.0, 9.0)

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)
plot_model(Lasso, polynomial=False, alphas=(0, 0.1, 1), random_state=42)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.subplot(122)
plot_model(Lasso, polynomial=True, alphas=(0, 10**-7, 1), tol=1, random_state=42)

plt.show()

# %% [markdown]
# ## ElasticNet

# %%
from sklearn.linear_model import ElasticNet

# %%
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
elastic_net.fit(X, y)
elastic_net.predict([[1.5]])
# Out:
# array([3.3678635])

# %%
plt.plot(X, y, "b.", linewidth=3)
y_r=elastic_net.predict(X)
plt.plot(X, y_r,  linewidth=1, label="Lasso")
plt.legend(loc="upper left", fontsize=15)
plt.xlabel("$x_1$", fontsize=18)
plt.axis([0, 4, 0, 9])
# Out:
# (0.0, 4.0, 0.0, 9.0)

# %% [markdown]
# ## Early Stopping

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(42)
m = 100
X = 6 * np.random.rand(m, 1) - 3
y = 2 + X + 0.5 * X**2 + np.random.randn(m, 1)

X_train, X_val, y_train, y_val = train_test_split(X[:50], y[:50].ravel(), test_size=0.5, random_state=10)

poly_scaler = Pipeline([
        ("poly_features", PolynomialFeatures(degree=90, include_bias=False)),
        ("std_scaler", StandardScaler()),
    ])

X_train_poly_scaled = poly_scaler.fit_transform(X_train)
X_val_poly_scaled = poly_scaler.transform(X_val)

sgd_reg = SGDRegressor(max_iter=1,
                       tol=-np.infty,
                       penalty=None,
                       eta0=0.0005,
                       warm_start=True,
                       learning_rate="constant",
                       random_state=42)

n_epochs = 500
train_errors, val_errors = [], []
for epoch in range(n_epochs):
    sgd_reg.fit(X_train_poly_scaled, y_train)
    y_train_predict = sgd_reg.predict(X_train_poly_scaled)
    y_val_predict = sgd_reg.predict(X_val_poly_scaled)
    train_errors.append(mean_squared_error(y_train, y_train_predict))
    val_errors.append(mean_squared_error(y_val, y_val_predict))

best_epoch = np.argmin(val_errors)
best_val_rmse = np.sqrt(val_errors[best_epoch])

plt.annotate('Best model',
             xy=(best_epoch, best_val_rmse),
             xytext=(best_epoch, best_val_rmse + 1),
             ha="center",
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=16,
            )

best_val_rmse -= 0.03  # just to make the graph look better
plt.plot([0, n_epochs], [best_val_rmse, best_val_rmse], "k:", linewidth=2)
plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="Validation set")
plt.plot(np.sqrt(train_errors), "r--", linewidth=2, label="Training set")
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("RMSE", fontsize=14)
plt.show()
